# %% [markdown]
# ECLIPSES - 2017 to 2021

# %%
type_eclipse = '''there have been three total, two annular and four partial eclipses.''' 
print(f"Between 2017 and 2021, {type_eclipse}")
# Out:
# Between 2017 and 2021, there have been three total, two annular and four partial eclipses.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array(["ANNULAR", "TOTAL", "PARTIAL"])
y = np.array([2, 3, 4])

plt.bar(x,y)
plt.show()
